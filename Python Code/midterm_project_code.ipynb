# %%
# Install necessary libraries
# !pip install mlxtend pandas
# Out:
# Requirement already satisfied: mlxtend in e:\teraboxdownload\lib\site-packages (0.23.1)
# Requirement already satisfied: pandas in e:\teraboxdownload\lib\site-packages (2.1.4)
# Requirement already satisfied: scipy>=1.2.1 in e:\teraboxdownload\lib\site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in e:\teraboxdownload\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in e:\teraboxdownload\lib\site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in e:\teraboxdownload\lib\site-packages (from mlxtend) (3.8.0)
# Requirement already satisfied: joblib>=0.13.2 in e:\teraboxdownload\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\teraboxdownload\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\teraboxdownload\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\teraboxdownload\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\teraboxdownload\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\teraboxdownload\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\teraboxdownload\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\teraboxdownload\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in e:\teraboxdownload\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in e:\teraboxdownload\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\teraboxdownload\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: six>=1.5 in e:\teraboxdownload\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\teraboxdownload\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)

# %%
# Import necessary libraries
import pandas as pd
from itertools import combinations
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import time

# Define file paths for the datasets (use raw strings to avoid escape sequence issues)
file_paths = {
    "Amazon": r"C:\Users\rithv\Downloads\Amazon_Updated_Transactions.csv",
    "BestBuy": r"C:\Users\rithv\Downloads\BestBuy_Updated_Transactions.csv",
    "KMart": r"C:\Users\rithv\Downloads\KMart_Updated_Transactions.csv",
    "Nike": r"C:\Users\rithv\Downloads\Nike_Updated_Transactions.csv"
}

# Load transactions from CSV files
def load_transactions(file_path):
    df = pd.read_csv(file_path)
    transactions = df['Items'].apply(lambda x: x.split(', ')).tolist()
    return transactions

# Brute Force Method for generating frequent itemsets
def generate_frequent_itemsets(transactions, support_threshold):
    item_count = {}
    for transaction in transactions:
        for item in transaction:
            item_count[item] = item_count.get(item, 0) + 1

    frequent_itemsets = {1: {item: count for item, count in item_count.items() if count / len(transactions) >= support_threshold}}

    k = 2
    while True:
        prev_itemsets = list(frequent_itemsets[k - 1].keys())
        new_itemsets = list(combinations(prev_itemsets, k))
        item_count = {}
        for transaction in transactions:
            transaction_set = set(transaction)
            for itemset in new_itemsets:
                if set(itemset).issubset(transaction_set):
                    item_count[itemset] = item_count.get(itemset, 0) + 1

        frequent_itemsets[k] = {itemset: count for itemset, count in item_count.items() if count / len(transactions) >= support_threshold}
        if not frequent_itemsets[k]:
            del frequent_itemsets[k]
            break
        k += 1
    return frequent_itemsets

# Apriori Algorithm
def apriori_algorithm(transactions, support_threshold, confidence_threshold):
    te = TransactionEncoder()
    te_ary = te.fit(transactions).transform(transactions)
    df = pd.DataFrame(te_ary, columns=te.columns_)

    frequent_itemsets = apriori(df, min_support=support_threshold, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=confidence_threshold)

    return frequent_itemsets, rules

# FP-Growth Algorithm
def fpgrowth_algorithm(transactions, support_threshold, confidence_threshold):
    te = TransactionEncoder()
    te_ary = te.fit(transactions).transform(transactions)
    df = pd.DataFrame(te_ary, columns=te.columns_)

    frequent_itemsets = fpgrowth(df, min_support=support_threshold, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=confidence_threshold)

    return frequent_itemsets, rules

# Timing function for comparison
def measure_execution_time(algorithm_func, *args):
    start_time = time.time()
    result = algorithm_func(*args)
    end_time = time.time()
    return result, end_time - start_time

# Main program loop
while True:
    # Prompt user to select a database or exit
    print("\nAvailable databases:")
    for i, name in enumerate(file_paths.keys(), 1):
        print(f"{i}. {name}")
    print("0. Exit")
    
    choice = int(input("Enter the number corresponding to the database you'd like to choose (or 0 to exit): "))

    # Exit the loop if the user chooses 0
    if choice == 0:
        print("Exiting the program.")
        break

    # Get the selected database name
    db_name = list(file_paths.keys())[choice - 1]

    # Load the selected transactions
    transactions = load_transactions(file_paths[db_name])
    print(f"Loaded {len(transactions)} transactions from {db_name}.")

    # Prompt user for support and confidence thresholds
    support_threshold = float(input("Enter support threshold in % (e.g., 10 for 10%): ")) / 100
    confidence_threshold = float(input("Enter confidence threshold in % (e.g., 20 for 20%): ")) / 100

    print(f"\nProcessing {db_name} with support {support_threshold * 100}% and confidence {confidence_threshold * 100}%...")

    # Brute Force
    bf_result, bf_time = measure_execution_time(generate_frequent_itemsets, transactions, support_threshold)
    print(f"\nBrute Force Frequent Itemsets:\n{bf_result}")
    print(f"Brute Force Time: {bf_time:.4f}s")

    # Apriori
    apriori_result, apriori_time = measure_execution_time(apriori_algorithm, transactions, support_threshold, confidence_threshold)
    print(f"\nApriori Frequent Itemsets:\n{apriori_result[0]}")
    print(f"Apriori Rules:\n{apriori_result[1]}")
    print(f"Apriori Time: {apriori_time:.4f}s")

    # FP-Growth
    fp_result, fp_time = measure_execution_time(fpgrowth_algorithm, transactions, support_threshold, confidence_threshold)
    print(f"\nFP-Growth Frequent Itemsets:\n{fp_result[0]}")
    print(f"FP-Growth Rules:\n{fp_result[1]}")
    print(f"FP-Growth Time: {fp_time:.4f}s")

    # Ask if the user wants to run another analysis
    continue_choice = input("\nDo you want to analyze another dataset? (yes/no): ").strip().lower()
    if continue_choice != 'yes':
        print("Exiting the program.")
        break
# Out:
# Available databases:
# 1. Amazon
# 2. BestBuy
# 3. KMart
# 4. Nike
# 0. Exit
# Enter the number corresponding to the database you'd like to choose (or 0 to exit):  4
# Loaded 20 transactions from Nike.
# Enter support threshold in % (e.g., 10 for 10%):  30
# Enter confidence threshold in % (e.g., 20 for 20%):  70
# Processing Nike with support 30.0% and confidence 70.0%...
#
# Brute Force Frequent Itemsets:
# {1: {'Running Shoe': 12, 'Socks': 9, 'Sweatshirts': 16, 'Modern Pants': 11, 'Soccer Shoe': 6, 'Swimming Shirt': 6, 'Rash Guard': 7}, 2: {('Running Shoe', 'Socks'): 6, ('Running Shoe', 'Sweatshirts'): 9, ('Running Shoe', 'Modern Pants'): 7, ('Socks', 'Sweatshirts'): 8, ('Sweatshirts', 'Modern Pants'): 9, ('Sweatshirts', 'Rash Guard'): 7}}
# Brute Force Time: 0.0000s
#
# Apriori Frequent Itemsets:
#     support                                   itemsets
# 0      0.55                             (Modern Pants)
# 1      0.35                               (Rash Guard)
# 2      0.60                             (Running Shoe)
# 3      0.30                              (Soccer Shoe)
# 4      0.45                                    (Socks)
# 5      0.80                              (Sweatshirts)
# 6      0.30                           (Swimming Shirt)
# 7      0.35               (Modern Pants, Running Shoe)
# 8      0.45                (Modern Pants, Sweatshirts)
# 9      0.35                  (Rash Guard, Sweatshirts)
# 10     0.30                      (Socks, Running Shoe)
# 11     0.45                (Running Shoe, Sweatshirts)
# 12     0.40                       (Socks, Sweatshirts)
# 13     0.30  (Modern Pants, Running Shoe, Sweatshirts)
# Apriori Rules:
#                     antecedents    consequents  antecedent support  \
# 0                (Modern Pants)  (Sweatshirts)                0.55
# 1                  (Rash Guard)  (Sweatshirts)                0.35
# 2                (Running Shoe)  (Sweatshirts)                0.60
# 3                       (Socks)  (Sweatshirts)                0.45
# 4  (Modern Pants, Running Shoe)  (Sweatshirts)                0.35
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0                 0.8     0.45    0.818182  1.022727      0.01         1.1
# 1                 0.8     0.35    1.000000  1.250000      0.07         inf
# 2                 0.8     0.45    0.750000  0.937500     -0.03         0.8
# 3                 0.8     0.40    0.888889  1.111111      0.04         1.8
# 4                 0.8     0.30    0.857143  1.071429      0.02         1.4
#
#    zhangs_metric
# 0       0.049383
# 1       0.307692
# 2      -0.142857
# 3       0.181818
# 4       0.102564
# Apriori Time: 0.0950s
#
# FP-Growth Frequent Itemsets:
#     support                                   itemsets
# 0      0.80                              (Sweatshirts)
# 1      0.60                             (Running Shoe)
# 2      0.55                             (Modern Pants)
# 3      0.45                                    (Socks)
# 4      0.30                              (Soccer Shoe)
# 5      0.35                               (Rash Guard)
# 6      0.30                           (Swimming Shirt)
# 7      0.45                (Running Shoe, Sweatshirts)
# 8      0.45                (Modern Pants, Sweatshirts)
# 9      0.35               (Modern Pants, Running Shoe)
# 10     0.30  (Modern Pants, Running Shoe, Sweatshirts)
# 11     0.40                       (Socks, Sweatshirts)
# 12     0.30                      (Socks, Running Shoe)
# 13     0.35                  (Rash Guard, Sweatshirts)
# FP-Growth Rules:
#                     antecedents    consequents  antecedent support  \
# 0                (Running Shoe)  (Sweatshirts)                0.60
# 1                (Modern Pants)  (Sweatshirts)                0.55
# 2  (Modern Pants, Running Shoe)  (Sweatshirts)                0.35
# 3                       (Socks)  (Sweatshirts)                0.45
# 4                  (Rash Guard)  (Sweatshirts)                0.35
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0                 0.8     0.45    0.750000  0.937500     -0.03         0.8
# 1                 0.8     0.45    0.818182  1.022727      0.01         1.1
# 2                 0.8     0.30    0.857143  1.071429      0.02         1.4
# 3                 0.8     0.40    0.888889  1.111111      0.04         1.8
# 4                 0.8     0.35    1.000000  1.250000      0.07         inf
#
#    zhangs_metric
# 0      -0.142857
# 1       0.049383
# 2       0.102564
# 3       0.181818
# 4       0.307692
# FP-Growth Time: 0.0157s
# Do you want to analyze another dataset? (yes/no):  yes
# Available databases:
# 1. Amazon
# 2. BestBuy
# 3. KMart
# 4. Nike
# 0. Exit
# Enter the number corresponding to the database you'd like to choose (or 0 to exit):  2
# Loaded 20 transactions from BestBuy.
# Enter support threshold in % (e.g., 10 for 10%):  10
# Enter confidence threshold in % (e.g., 20 for 20%):  50
# Processing BestBuy with support 10.0% and confidence 50.0%...
#
# Brute Force Frequent Itemsets:
# {1: {'Desk Top': 5, 'Printer': 8, 'Flash Drive': 9, 'Microsoft Office': 9, 'Speakers': 6, 'Anti-Virus': 13, 'Lab Top': 15, 'Lab Top Case': 11, 'External Hard-Drive': 6, 'Digital Camera': 6}, 2: {('Desk Top', 'Flash Drive'): 3, ('Desk Top', 'Microsoft Office'): 3, ('Desk Top', 'Speakers'): 3, ('Desk Top', 'Anti-Virus'): 2, ('Printer', 'Flash Drive'): 5, ('Printer', 'Microsoft Office'): 3, ('Printer', 'Speakers'): 3, ('Printer', 'Anti-Virus'): 6, ('Flash Drive', 'Microsoft Office'): 4, ('Flash Drive', 'Speakers'): 2, ('Flash Drive', 'Anti-Virus'): 8, ('Microsoft Office', 'Speakers'): 2, ('Microsoft Office', 'Anti-Virus'): 6, ('Speakers', 'Anti-Virus'): 2, ('Flash Drive', 'Lab Top'): 7, ('Flash Drive', 'Lab Top Case'): 5, ('Microsoft Office', 'Lab Top'): 7, ('Microsoft Office', 'Lab Top Case'): 4, ('Anti-Virus', 'Lab Top'): 10, ('Anti-Virus', 'Lab Top Case'): 7, ('Lab Top', 'Lab Top Case'): 9, ('Printer', 'Lab Top'): 6, ('Printer', 'Lab Top Case'): 5, ('Printer', 'External Hard-Drive'): 3, ('Flash Drive', 'External Hard-Drive'): 3, ('Microsoft Office', 'External Hard-Drive'): 3, ('Anti-Virus', 'External Hard-Drive'): 3, ('Lab Top', 'External Hard-Drive'): 5, ('Lab Top Case', 'External Hard-Drive'): 3, ('Speakers', 'Lab Top'): 5, ('Speakers', 'Lab Top Case'): 3, ('Speakers', 'External Hard-Drive'): 2, ('Desk Top', 'Lab Top'): 4, ('Anti-Virus', 'Digital Camera'): 3, ('Desk Top', 'Lab Top Case'): 2, ('Lab Top Case', 'Digital Camera'): 4, ('Microsoft Office', 'Digital Camera'): 2, ('Lab Top', 'Digital Camera'): 2}}
# Brute Force Time: 0.0833s
#
# Apriori Frequent Itemsets:
#      support                                           itemsets
# 0       0.65                                       (Anti-Virus)
# 1       0.25                                         (Desk Top)
# 2       0.30                                   (Digital Camera)
# 3       0.30                              (External Hard-Drive)
# 4       0.45                                      (Flash Drive)
# ..       ...                                                ...
# 120     0.10  (Microsoft Office, Flash Drive, Lab Top Case, ...
# 121     0.10  (Flash Drive, Lab Top Case, Printer, Anti-Viru...
# 122     0.10  (Microsoft Office, Flash Drive, Printer, Anti-...
# 123     0.10  (Flash Drive, Lab Top Case, Printer, Lab Top, ...
# 124     0.10  (Flash Drive, Lab Top Case, Printer, Anti-Viru...
#
# [125 rows x 2 columns]
# Apriori Rules:
#                                     antecedents  \
# 0                              (Digital Camera)
# 1                         (External Hard-Drive)
# 2                                  (Anti-Virus)
# 3                                 (Flash Drive)
# 4                                  (Anti-Virus)
# ..                                          ...
# 452  (Anti-Virus, Lab Top, External Hard-Drive)
# 453          (Flash Drive, External Hard-Drive)
# 454         (Lab Top Case, External Hard-Drive)
# 455              (Printer, External Hard-Drive)
# 456           (Anti-Virus, External Hard-Drive)
#
#                                           consequents  antecedent support  \
# 0                                        (Anti-Virus)                0.30
# 1                                        (Anti-Virus)                0.30
# 2                                       (Flash Drive)                0.65
# 3                                        (Anti-Virus)                0.45
# 4                                           (Lab Top)                0.65
# ..                                                ...                 ...
# 452              (Printer, Flash Drive, Lab Top Case)                0.15
# 453      (Printer, Anti-Virus, Lab Top Case, Lab Top)                0.15
# 454       (Printer, Anti-Virus, Flash Drive, Lab Top)                0.15
# 455  (Anti-Virus, Flash Drive, Lab Top, Lab Top Case)                0.15
# 456     (Printer, Flash Drive, Lab Top, Lab Top Case)                0.15
#
#      consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.65     0.15    0.500000  0.769231   -0.0450    0.700000
# 1                  0.65     0.15    0.500000  0.769231   -0.0450    0.700000
# 2                  0.45     0.40    0.615385  1.367521    0.1075    1.430000
# 3                  0.65     0.40    0.888889  1.367521    0.1075    3.150000
# 4                  0.75     0.50    0.769231  1.025641    0.0125    1.083333
# ..                  ...      ...         ...       ...       ...         ...
# 452                0.15     0.10    0.666667  4.444444    0.0775    2.550000
# 453                0.15     0.10    0.666667  4.444444    0.0775    2.550000
# 454                0.15     0.10    0.666667  4.444444    0.0775    2.550000
# 455                0.20     0.10    0.666667  3.333333    0.0700    2.400000
# 456                0.10     0.10    0.666667  6.666667    0.0850    2.700000
#
#      zhangs_metric
# 0        -0.300000
# 1        -0.300000
# 2         0.767857
# 3         0.488636
# 4         0.071429
# ..             ...
# 452       0.911765
# 453       0.911765
# 454       0.911765
# 455       0.823529
# 456       1.000000
#
# [457 rows x 10 columns]
# Apriori Time: 0.0196s
#
# FP-Growth Frequent Itemsets:
#      support                                    itemsets
# 0       0.65                                (Anti-Virus)
# 1       0.45                          (Microsoft Office)
# 2       0.45                               (Flash Drive)
# 3       0.40                                   (Printer)
# 4       0.30                                  (Speakers)
# ..       ...                                         ...
# 120     0.20              (Lab Top Case, Digital Camera)
# 121     0.10          (Microsoft Office, Digital Camera)
# 122     0.10                   (Lab Top, Digital Camera)
# 123     0.10  (Anti-Virus, Lab Top Case, Digital Camera)
# 124     0.10     (Lab Top Case, Lab Top, Digital Camera)
#
# [125 rows x 2 columns]
# FP-Growth Rules:
#                         antecedents         consequents  antecedent support  \
# 0                      (Anti-Virus)           (Lab Top)                0.65
# 1                         (Lab Top)        (Anti-Virus)                0.75
# 2                (Microsoft Office)        (Anti-Virus)                0.45
# 3                (Microsoft Office)           (Lab Top)                0.45
# 4             (Anti-Virus, Lab Top)  (Microsoft Office)                0.50
# ..                              ...                 ...                 ...
# 452                (Digital Camera)      (Lab Top Case)                0.30
# 453    (Anti-Virus, Digital Camera)      (Lab Top Case)                0.15
# 454  (Lab Top Case, Digital Camera)        (Anti-Virus)                0.20
# 455  (Lab Top Case, Digital Camera)           (Lab Top)                0.20
# 456       (Lab Top, Digital Camera)      (Lab Top Case)                0.10
#
#      consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.75     0.50    0.769231  1.025641    0.0125    1.083333
# 1                  0.65     0.50    0.666667  1.025641    0.0125    1.050000
# 2                  0.65     0.30    0.666667  1.025641    0.0075    1.050000
# 3                  0.75     0.35    0.777778  1.037037    0.0125    1.125000
# 4                  0.45     0.25    0.500000  1.111111    0.0250    1.100000
# ..                  ...      ...         ...       ...       ...         ...
# 452                0.55     0.20    0.666667  1.212121    0.0350    1.350000
# 453                0.55     0.10    0.666667  1.212121    0.0175    1.350000
# 454                0.65     0.10    0.500000  0.769231   -0.0300    0.700000
# 455                0.75     0.10    0.500000  0.666667   -0.0500    0.500000
# 456                0.55     0.10    1.000000  1.818182    0.0450         inf
#
#      zhangs_metric
# 0         0.071429
# 1         0.100000
# 2         0.045455
# 3         0.064935
# 4         0.200000
# ..             ...
# 452       0.250000
# 453       0.205882
# 454      -0.272727
# 455      -0.384615
# 456       0.500000
#
# [457 rows x 10 columns]
# FP-Growth Time: 0.0061s
# Do you want to analyze another dataset? (yes/no):  no
# Exiting the program.
